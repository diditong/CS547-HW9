# %%
# Import modules
from __future__ import print_function

import os
import sys
import gzip
import copy
import shutil
import struct
import itertools
import numpy as np
from random import shuffle
from random import randint
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

try:
    from urllib.request import urlretrieve
except ImportError:
    from urllib import urlretrieve

# Config matplotlib for inline plotting
# %matplotlib inline

# %%
## Dataloader Function Definitions
def loadData(url, nimage):
    print ('Downloading ' + url)
    gzfile_name, h = urlretrieve(url, './delete.me')
    print ('Done.')
    try:
        with gzip.open(gzfile_name) as gz:
            n = struct.unpack('I', gz.read(4))
            n = struct.unpack('>I', gz.read(4))[0]
            nrow = struct.unpack('>I', gz.read(4))[0]
            ncol = struct.unpack('>I', gz.read(4))[0]
            res = np.frombuffer(gz.read(nimage * nrow * ncol), dtype = np.uint8)
    finally:
        os.remove(gzfile_name)
    return res.reshape((nimage, nrow * ncol))

def loadLabels(url, nimage):
    print ('Downloading ' + url)
    gzfile_name, h = urlretrieve(url, './delete.me')
    print ('Done.')
    try:
        with gzip.open(gzfile_name) as gz:
            n = struct.unpack('I', gz.read(4))
            n = struct.unpack('>I', gz.read(4))
            res = np.frombuffer(gz.read(nimage), dtype = np.uint8)
    finally:
        os.remove(gzfile_name)
    return res.reshape((nimage, 1))

def download(dataurl, labelsurl, nimage):
    data = loadData(dataurl, nimage)
    labels = loadLabels(labelsurl, nimage)
    return np.hstack((data, labels))

# %%
## Download Data From Remote Source
# URLs for the train image and label data
train_image_url = 'http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz'
train_labels_url = 'http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz'
num_train_samples = 60000
# Download train data
print("Downloading train data")
train = download(train_image_url, train_labels_url, num_train_samples)
# URLs for the test image and label data
test_image_url = 'http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz'
test_labels_url = 'http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz'
num_test_samples = 10000
# Download test data
print("Downloading test data")
test = download(test_image_url, test_labels_url, num_test_samples)

## Prepare Train and Test data
# Separate X and Y from data
Xtrain = train[:,0:-1]
Xtest = test[:,0:-1]
Ytrain = train[:,-1]
Ytest = test[:,-1]
Xtrain = Xtrain.reshape(60000,28,28)
Xtest = Xtest.reshape(10000,28,28)
# Out:
# Downloading train data
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Done.
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Done.
# Downloading test data
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Done.
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Done.

# %%
## Hyperparameters for the layers and filters
num_digits = 10 
l_filter = 5
l_filter = 5
num_filters = 5
l_output_map = 28-l_filter+1 

## Initialize the parameters for the Convolutional Neural Network
parameters = {
    'K': np.random.randn(l_filter, l_filter, num_filters)/np.sqrt(l_filter*l_filter),
    'W': np.random.randn(num_digits, l_output_map, l_output_map, num_filters)/np.sqrt(l_output_map*l_output_map),
    'b': np.random.randn(num_digits) 
}
parameters_grads = copy.deepcopy(parameters)

## Define the iterable tables for use in the conv function
i1= range(l_output_map)
i2 = range(l_output_map)
i3= range(l_filter)
i4 = range(l_filter)
i5 = range(num_filters)
iteratable_forward = list(itertools.product(i1, i2, i5))
iteratable_backward= list(itertools.product(i3, i4, i5))

# %%
## Define the softmax function
def softmax(z):
    return np.exp(z)/np.sum(np.exp(z))

## Define the convolution function
def conv(X, K, iteratable, l_f):
    conv_Z = np.array([np.tensordot(K[:,:,ijk[2]],X[ijk[0]:ijk[0]+l_f,ijk[1]:ijk[1]+l_f], axes=((0,1), (0,1))) for ijk in iteratable])
    return conv_Z

## Define the activation function tanh
def tanh(M):
    return np.tanh(M)

## Define the derivative of the activation function
def tanh_p(M):
    return 1.0-np.tanh(M)**2

## Define the feed forward function for computing intermediate layers
def feedforward(x, y): 
    Z = conv(x, parameters['K'], iteratable_forward, l_filter).reshape(l_output_map, l_output_map, num_filters) 
    H = tanh(Z)
    U = np.tensordot(parameters['W'], H, axes = ((1,2,3),(0,1,2))) + parameters['b']
    f = softmax(U)
    return Z, H, f

## Define the backpropogation function for updating parameters
def backpropagate(x, y, Z, H, f):
    drdU = -1.0*f
    drdU[y] = (drdU[y] + 1.0) 
    drdU = -drdU
    drdb = drdU
    drdW = np.tensordot(drdU.T, H, axes = 0)[0]
    delta = np.tensordot(drdU.T, parameters['W'], axes = 1)[0] 
    drdK =  conv(x, np.multiply(delta, tanh_p(Z)), iteratable_backward, 28-l_filter+1).reshape(l_filter, l_filter, num_filters)
    return drdb,drdW,drdK
        
## Predict function used to compute accuracy on a dataset
def predict(Xdata, Ydata):
    total_correct = 0
    for index in range(len(Xdata)):
        y = Ydata[index]
        x = Xdata[index][:]
        _, _, p = feedforward(x, y)
        prediction = np.argmax(p)
        if (prediction == y): 
            total_correct += 1
    accuracy = total_correct/np.float(len(Xdata))
    return accuracy

# %%
## Define parameters for training
lr = 1e-2
num_epoch = 20

## Implement Training with SGD
for epoch in range(num_epoch):
    if (epoch > 5):
        lr = 1e-3
    if (epoch > 10):
        lr = 1e-4
    if (epoch > 15):
        lr = 1e-5
        
    # Do Feedforward and Backpropagate, and update parameters according to SGD 
    num_correct_predictions = 0
    for n in range(len(Xtrain)):
        if (n%100 == 0):
            print("Iteration #", n, "completed out of ", len(Xtrain),"iterations")
        n_random = randint(0,len(Xtrain)-1)
        y = Ytrain[n_random]
        x = Xtrain[n_random][:]
        Z, H, f = feedforward(x, y)
        prediction = np.argmax(f)
        if (prediction == y):
            num_correct_predictions += 1
        drdb,drdW,drdK = backpropagate(x, y, Z, H, f)
        parameters['W'] -= lr*drdW
        parameters['b'] -= lr*drdb
        parameters['K'] -= lr*drdK
    print('For epoch ', epoch,'/num_epoch', ', accuracy in training set = ', num_correct_predictions/len(Xtrain))

## Compute the test accuracy 
test_accuracy = predict(Xtest, Ytest)
print('Accuracy in testing set =', test_accuracy)
# Out:
# Iteration # 0 completed out of  60000 iterations
# Iteration # 100 completed out of  60000 iterations
# Iteration # 200 completed out of  60000 iterations
# Iteration # 300 completed out of  60000 iterations
# Iteration # 400 completed out of  60000 iterations
# Iteration # 500 completed out of  60000 iterations
# Iteration # 600 completed out of  60000 iterations
# Iteration # 700 completed out of  60000 iterations
# Iteration # 800 completed out of  60000 iterations
# Iteration # 900 completed out of  60000 iterations
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Iteration # 1000 completed out of  60000 iterations
# Iteration # 1100 completed out of  60000 iterations
# Iteration # 1200 completed out of  60000 iterations
# Iteration # 1300 completed out of  60000 iterations
# Iteration # 1400 completed out of  60000 iterations
# Iteration # 1500 completed out of  60000 iterations
# Iteration # 1600 completed out of  60000 iterations
# Iteration # 1700 completed out of  60000 iterations
# Iteration # 1800 completed out of  60000 iterations
# Iteration # 1900 completed out of  60000 iterations
# Iteration # 2000 completed out of  60000 iterations
# Iteration # 2100 completed out of  60000 iterations
# Iteration # 2200 completed out of  60000 iterations
# Iteration # 2300 completed out of  60000 iterations
# Iteration # 2400 completed out of  60000 iterations
# Iteration # 2500 completed out of  60000 iterations
# Iteration # 2600 completed out of  60000 iterations
# Iteration # 2700 completed out of  60000 iterations
# Iteration # 2800 completed out of  60000 iterations
# Iteration # 2900 completed out of  60000 iterations
# Iteration # 3000 completed out of  60000 iterations
# Iteration # 3100 completed out of  60000 iterations
# Iteration # 3200 completed out of  60000 iterations
# Iteration # 3300 completed out of  60000 iterations
# Iteration # 3400 completed out of  60000 iterations
# Iteration # 3500 completed out of  60000 iterations
# Iteration # 3600 completed out of  60000 iterations
# Iteration # 3700 completed out of  60000 iterations
# Iteration # 3800 completed out of  60000 iterations
# Iteration # 3900 completed out of  60000 iterations
# Iteration # 4000 completed out of  60000 iterations
# Iteration # 4100 completed out of  60000 iterations
# Iteration # 4200 completed out of  60000 iterations
# Iteration # 4300 completed out of  60000 iterations
# Iteration # 4400 completed out of  60000 iterations
# Iteration # 4500 completed out of  60000 iterations
# Iteration # 4600 completed out of  60000 iterations
# Iteration # 4700 completed out of  60000 iterations
# Iteration # 4800 completed out of  60000 iterations
# Iteration # 4900 completed out of  60000 iterations
# Iteration # 5000 completed out of  60000 iterations
# Iteration # 5100 completed out of  60000 iterations
# Iteration # 5200 completed out of  60000 iterations
# Iteration # 5300 completed out of  60000 iterations
# Iteration # 5400 completed out of  60000 iterations
# Iteration # 5500 completed out of  60000 iterations
# Iteration # 5600 completed out of  60000 iterations
# Iteration # 5700 completed out of  60000 iterations
# Iteration # 5800 completed out of  60000 iterations
# Iteration # 5900 completed out of  60000 iterations
# Iteration # 6000 completed out of  60000 iterations
# Iteration # 6100 completed out of  60000 iterations
# Iteration # 6200 completed out of  60000 iterations
# Iteration # 6300 completed out of  60000 iterations
# Iteration # 6400 completed out of  60000 iterations
# Iteration # 6500 completed out of  60000 iterations
# Iteration # 6600 completed out of  60000 iterations
# Iteration # 6700 completed out of  60000 iterations
# Iteration # 6800 completed out of  60000 iterations
# Iteration # 6900 completed out of  60000 iterations
# Iteration # 7000 completed out of  60000 iterations
# Iteration # 7100 completed out of  60000 iterations
# Iteration # 7200 completed out of  60000 iterations
# Iteration # 7300 completed out of  60000 iterations
# Iteration # 7400 completed out of  60000 iterations
# Iteration # 7500 completed out of  60000 iterations
# Iteration # 7600 completed out of  60000 iterations
# Iteration # 7700 completed out of  60000 iterations
# Iteration # 7800 completed out of  60000 iterations
# Iteration # 7900 completed out of  60000 iterations
# Iteration # 8000 completed out of  60000 iterations
# Iteration # 8100 completed out of  60000 iterations
# Iteration # 8200 completed out of  60000 iterations
# Iteration # 8300 completed out of  60000 iterations
# Iteration # 8400 completed out of  60000 iterations
# Iteration # 8500 completed out of  60000 iterations
# Iteration # 8600 completed out of  60000 iterations
# Iteration # 8700 completed out of  60000 iterations
# Iteration # 8800 completed out of  60000 iterations
# Iteration # 8900 completed out of  60000 iterations
# Iteration # 9000 completed out of  60000 iterations
# Iteration # 9100 completed out of  60000 iterations
# Iteration # 9200 completed out of  60000 iterations
# Iteration # 9300 completed out of  60000 iterations
# Iteration # 9400 completed out of  60000 iterations
# Iteration # 9500 completed out of  60000 iterations
# Iteration # 9600 completed out of  60000 iterations
# Iteration # 9700 completed out of  60000 iterations
# Iteration # 9800 completed out of  60000 iterations
# Iteration # 9900 completed out of  60000 iterations
# Iteration # 10000 completed out of  60000 iterations
# Iteration # 10100 completed out of  60000 iterations
# Iteration # 10200 completed out of  60000 iterations
# Iteration # 10300 completed out of  60000 iterations
# Iteration # 10400 completed out of  60000 iterations
# Iteration # 10500 completed out of  60000 iterations
# Iteration # 10600 completed out of  60000 iterations
# Iteration # 10700 completed out of  60000 iterations
# Iteration # 10800 completed out of  60000 iterations
# Iteration # 10900 completed out of  60000 iterations
# Iteration # 11000 completed out of  60000 iterations
# Iteration # 11100 completed out of  60000 iterations
# Iteration # 11200 completed out of  60000 iterations
# Iteration # 11300 completed out of  60000 iterations
# Iteration # 11400 completed out of  60000 iterations
# Iteration # 11500 completed out of  60000 iterations
# Iteration # 11600 completed out of  60000 iterations
# Iteration # 11700 completed out of  60000 iterations
# Iteration # 11800 completed out of  60000 iterations
# Iteration # 11900 completed out of  60000 iterations
# Iteration # 12000 completed out of  60000 iterations
# Iteration # 12100 completed out of  60000 iterations
# Iteration # 12200 completed out of  60000 iterations
# Iteration # 12300 completed out of  60000 iterations
# Iteration # 12400 completed out of  60000 iterations
# Iteration # 12500 completed out of  60000 iterations
# Iteration # 12600 completed out of  60000 iterations
# Iteration # 12700 completed out of  60000 iterations
# Iteration # 12800 completed out of  60000 iterations
# Iteration # 12900 completed out of  60000 iterations
# Iteration # 13000 completed out of  60000 iterations
# Iteration # 13100 completed out of  60000 iterations
# Iteration # 13200 completed out of  60000 iterations
# Iteration # 13300 completed out of  60000 iterations
# Iteration # 13400 completed out of  60000 iterations
# Iteration # 13500 completed out of  60000 iterations
# Iteration # 13600 completed out of  60000 iterations
# Iteration # 13700 completed out of  60000 iterations
# Iteration # 13800 completed out of  60000 iterations
# Iteration # 13900 completed out of  60000 iterations
# Iteration # 14000 completed out of  60000 iterations
# Iteration # 14100 completed out of  60000 iterations
# Iteration # 14200 completed out of  60000 iterations
# Iteration # 14300 completed out of  60000 iterations
# Iteration # 14400 completed out of  60000 iterations
# Iteration # 14500 completed out of  60000 iterations
# Iteration # 14600 completed out of  60000 iterations
# Iteration # 14700 completed out of  60000 iterations
# Iteration # 14800 completed out of  60000 iterations
# Iteration # 14900 completed out of  60000 iterations
# Iteration # 15000 completed out of  60000 iterations
# Iteration # 15100 completed out of  60000 iterations
# Iteration # 15200 completed out of  60000 iterations
# Iteration # 15300 completed out of  60000 iterations
# Iteration # 15400 completed out of  60000 iterations
# Iteration # 15500 completed out of  60000 iterations
# Iteration # 15600 completed out of  60000 iterations
# Iteration # 15700 completed out of  60000 iterations
# Iteration # 15800 completed out of  60000 iterations
# Iteration # 15900 completed out of  60000 iterations
# Iteration # 16000 completed out of  60000 iterations
# Iteration # 16100 completed out of  60000 iterations
# Iteration # 16200 completed out of  60000 iterations
# Iteration # 16300 completed out of  60000 iterations
# Iteration # 16400 completed out of  60000 iterations
# Iteration # 16500 completed out of  60000 iterations
# Iteration # 16600 completed out of  60000 iterations
# Iteration # 16700 completed out of  60000 iterations
# Iteration # 16800 completed out of  60000 iterations
# Iteration # 16900 completed out of  60000 iterations
# Iteration # 17000 completed out of  60000 iterations
# Iteration # 17100 completed out of  60000 iterations
# Iteration # 17200 completed out of  60000 iterations
# Iteration # 17300 completed out of  60000 iterations
# Iteration # 17400 completed out of  60000 iterations
# Iteration # 17500 completed out of  60000 iterations
# Iteration # 17600 completed out of  60000 iterations
# Iteration # 17700 completed out of  60000 iterations
# Iteration # 17800 completed out of  60000 iterations
# Iteration # 17900 completed out of  60000 iterations
# Iteration # 18000 completed out of  60000 iterations
# Iteration # 18100 completed out of  60000 iterations
# Iteration # 18200 completed out of  60000 iterations
# Iteration # 18300 completed out of  60000 iterations
# Iteration # 18400 completed out of  60000 iterations
# Iteration # 18500 completed out of  60000 iterations
# Iteration # 18600 completed out of  60000 iterations
# Iteration # 18700 completed out of  60000 iterations
# Iteration # 18800 completed out of  60000 iterations
# Iteration # 18900 completed out of  60000 iterations
# Iteration # 19000 completed out of  60000 iterations
# Iteration # 19100 completed out of  60000 iterations
# Iteration # 19200 completed out of  60000 iterations
# Iteration # 19300 completed out of  60000 iterations
# Iteration # 19400 completed out of  60000 iterations
# Iteration # 19500 completed out of  60000 iterations
# Iteration # 19600 completed out of  60000 iterations
# Iteration # 19700 completed out of  60000 iterations
# Iteration # 19800 completed out of  60000 iterations
# Iteration # 19900 completed out of  60000 iterations
# Iteration # 20000 completed out of  60000 iterations
# Iteration # 20100 completed out of  60000 iterations
# Iteration # 20200 completed out of  60000 iterations
# Iteration # 20300 completed out of  60000 iterations
# Iteration # 20400 completed out of  60000 iterations
# Iteration # 20500 completed out of  60000 iterations
# Iteration # 20600 completed out of  60000 iterations
# Iteration # 20700 completed out of  60000 iterations
# Iteration # 20800 completed out of  60000 iterations
# Iteration # 20900 completed out of  60000 iterations
# Iteration # 21000 completed out of  60000 iterations
# Iteration # 21100 completed out of  60000 iterations
# Iteration # 21200 completed out of  60000 iterations
# Iteration # 21300 completed out of  60000 iterations
# Iteration # 21400 completed out of  60000 iterations
# Iteration # 21500 completed out of  60000 iterations
# Iteration # 21600 completed out of  60000 iterations
# Iteration # 21700 completed out of  60000 iterations
# Iteration # 21800 completed out of  60000 iterations
# Iteration # 21900 completed out of  60000 iterations
# Iteration # 22000 completed out of  60000 iterations
# Iteration # 22100 completed out of  60000 iterations
# Iteration # 22200 completed out of  60000 iterations
# Iteration # 22300 completed out of  60000 iterations
# Iteration # 22400 completed out of  60000 iterations
# Iteration # 22500 completed out of  60000 iterations
# Iteration # 22600 completed out of  60000 iterations
# Iteration # 22700 completed out of  60000 iterations
# Iteration # 22800 completed out of  60000 iterations
# Iteration # 22900 completed out of  60000 iterations
# Iteration # 23000 completed out of  60000 iterations
# Iteration # 23100 completed out of  60000 iterations
# Iteration # 23200 completed out of  60000 iterations
# Iteration # 23300 completed out of  60000 iterations
# Iteration # 23400 completed out of  60000 iterations
# Iteration # 23500 completed out of  60000 iterations
# Iteration # 23600 completed out of  60000 iterations
# Iteration # 23700 completed out of  60000 iterations
# Iteration # 23800 completed out of  60000 iterations
# Iteration # 23900 completed out of  60000 iterations
# Iteration # 24000 completed out of  60000 iterations
# Iteration # 24100 completed out of  60000 iterations
# Iteration # 24200 completed out of  60000 iterations
# Iteration # 24300 completed out of  60000 iterations
# Iteration # 24400 completed out of  60000 iterations
# Iteration # 24500 completed out of  60000 iterations
# Iteration # 24600 completed out of  60000 iterations
# Iteration # 24700 completed out of  60000 iterations
# Iteration # 24800 completed out of  60000 iterations
# Iteration # 24900 completed out of  60000 iterations
# Iteration # 25000 completed out of  60000 iterations
# Iteration # 25100 completed out of  60000 iterations
# Iteration # 25200 completed out of  60000 iterations
# Iteration # 25300 completed out of  60000 iterations
# Iteration # 25400 completed out of  60000 iterations
# Iteration # 25500 completed out of  60000 iterations
# Iteration # 25600 completed out of  60000 iterations
# Iteration # 25700 completed out of  60000 iterations
# Iteration # 25800 completed out of  60000 iterations
# Iteration # 25900 completed out of  60000 iterations
# Iteration # 26000 completed out of  60000 iterations
# Iteration # 26100 completed out of  60000 iterations
# Iteration # 26200 completed out of  60000 iterations
# Iteration # 26300 completed out of  60000 iterations
# Iteration # 26400 completed out of  60000 iterations
# Iteration # 26500 completed out of  60000 iterations
# Iteration # 26600 completed out of  60000 iterations
# Iteration # 26700 completed out of  60000 iterations
# Iteration # 26800 completed out of  60000 iterations
# Iteration # 26900 completed out of  60000 iterations
# Iteration # 27000 completed out of  60000 iterations
# Iteration # 27100 completed out of  60000 iterations
# Iteration # 27200 completed out of  60000 iterations
# Iteration # 27300 completed out of  60000 iterations
# Iteration # 27400 completed out of  60000 iterations
# Iteration # 27500 completed out of  60000 iterations
# Iteration # 27600 completed out of  60000 iterations
# Iteration # 27700 completed out of  60000 iterations
# Iteration # 27800 completed out of  60000 iterations
# Iteration # 27900 completed out of  60000 iterations
# Iteration # 28000 completed out of  60000 iterations
# Iteration # 28100 completed out of  60000 iterations
# Iteration # 28200 completed out of  60000 iterations
# Iteration # 28300 completed out of  60000 iterations
# Iteration # 28400 completed out of  60000 iterations
# Iteration # 28500 completed out of  60000 iterations
# Iteration # 28600 completed out of  60000 iterations
# Iteration # 28700 completed out of  60000 iterations
# Iteration # 28800 completed out of  60000 iterations
# Iteration # 28900 completed out of  60000 iterations
# Iteration # 29000 completed out of  60000 iterations
# Iteration # 29100 completed out of  60000 iterations
# Iteration # 29200 completed out of  60000 iterations
# Iteration # 29300 completed out of  60000 iterations
# Iteration # 29400 completed out of  60000 iterations
# Iteration # 29500 completed out of  60000 iterations
# Iteration # 29600 completed out of  60000 iterations
# Iteration # 29700 completed out of  60000 iterations
# Iteration # 29800 completed out of  60000 iterations
# Iteration # 29900 completed out of  60000 iterations
# Iteration # 30000 completed out of  60000 iterations
# Iteration # 30100 completed out of  60000 iterations
# Iteration # 30200 completed out of  60000 iterations
# Iteration # 30300 completed out of  60000 iterations
# Iteration # 30400 completed out of  60000 iterations
# Iteration # 30500 completed out of  60000 iterations
# Iteration # 30600 completed out of  60000 iterations
# Iteration # 30700 completed out of  60000 iterations
# Iteration # 30800 completed out of  60000 iterations
# Iteration # 30900 completed out of  60000 iterations
# Iteration # 31000 completed out of  60000 iterations
# Iteration # 31100 completed out of  60000 iterations
# Iteration # 31200 completed out of  60000 iterations
# Iteration # 31300 completed out of  60000 iterations
# Iteration # 31400 completed out of  60000 iterations
# Iteration # 31500 completed out of  60000 iterations
# Iteration # 31600 completed out of  60000 iterations
# Iteration # 31700 completed out of  60000 iterations
# Iteration # 31800 completed out of  60000 iterations
# Iteration # 31900 completed out of  60000 iterations
# Iteration # 32000 completed out of  60000 iterations
# Iteration # 32100 completed out of  60000 iterations
# Iteration # 32200 completed out of  60000 iterations
# Iteration # 32300 completed out of  60000 iterations
# Iteration # 32400 completed out of  60000 iterations
# Iteration # 32500 completed out of  60000 iterations
# Iteration # 32600 completed out of  60000 iterations
# Iteration # 32700 completed out of  60000 iterations
# Iteration # 32800 completed out of  60000 iterations
# Iteration # 32900 completed out of  60000 iterations
# Iteration # 33000 completed out of  60000 iterations
# Iteration # 33100 completed out of  60000 iterations
# Iteration # 33200 completed out of  60000 iterations
# Iteration # 33300 completed out of  60000 iterations
# Iteration # 33400 completed out of  60000 iterations
# Iteration # 33500 completed out of  60000 iterations
# Iteration # 33600 completed out of  60000 iterations
# Iteration # 33700 completed out of  60000 iterations
# Iteration # 33800 completed out of  60000 iterations
# Iteration # 33900 completed out of  60000 iterations
# Iteration # 34000 completed out of  60000 iterations
# Iteration # 34100 completed out of  60000 iterations
# Iteration # 34200 completed out of  60000 iterations
# Iteration # 34300 completed out of  60000 iterations
# Iteration # 34400 completed out of  60000 iterations
# Iteration # 34500 completed out of  60000 iterations
# Iteration # 34600 completed out of  60000 iterations
# Iteration # 34700 completed out of  60000 iterations
# Iteration # 34800 completed out of  60000 iterations
# Iteration # 34900 completed out of  60000 iterations
# Iteration # 35000 completed out of  60000 iterations
# Iteration # 35100 completed out of  60000 iterations
# Iteration # 35200 completed out of  60000 iterations
# Iteration # 35300 completed out of  60000 iterations
# Iteration # 35400 completed out of  60000 iterations
# Iteration # 35500 completed out of  60000 iterations
# Iteration # 35600 completed out of  60000 iterations
# Iteration # 35700 completed out of  60000 iterations
# Iteration # 35800 completed out of  60000 iterations
# Iteration # 35900 completed out of  60000 iterations
# Iteration # 36000 completed out of  60000 iterations
# Iteration # 36100 completed out of  60000 iterations
# Iteration # 36200 completed out of  60000 iterations
# Iteration # 36300 completed out of  60000 iterations
# Iteration # 36400 completed out of  60000 iterations
# Iteration # 36500 completed out of  60000 iterations
# Iteration # 36600 completed out of  60000 iterations
# Iteration # 36700 completed out of  60000 iterations
# Iteration # 36800 completed out of  60000 iterations
# Iteration # 36900 completed out of  60000 iterations
# Iteration # 37000 completed out of  60000 iterations
# Iteration # 37100 completed out of  60000 iterations
# Iteration # 37200 completed out of  60000 iterations
# Iteration # 37300 completed out of  60000 iterations
# Iteration # 37400 completed out of  60000 iterations
# Iteration # 37500 completed out of  60000 iterations
# Iteration # 37600 completed out of  60000 iterations
# Iteration # 37700 completed out of  60000 iterations
# Iteration # 37800 completed out of  60000 iterations
# Iteration # 37900 completed out of  60000 iterations
# Iteration # 38000 completed out of  60000 iterations
# Iteration # 38100 completed out of  60000 iterations
# Iteration # 38200 completed out of  60000 iterations
# Iteration # 38300 completed out of  60000 iterations
# Iteration # 38400 completed out of  60000 iterations
# Iteration # 38500 completed out of  60000 iterations
# Iteration # 38600 completed out of  60000 iterations
# Iteration # 38700 completed out of  60000 iterations
# Iteration # 38800 completed out of  60000 iterations
# Iteration # 38900 completed out of  60000 iterations
# Iteration # 39000 completed out of  60000 iterations
# Iteration # 39100 completed out of  60000 iterations
# Iteration # 39200 completed out of  60000 iterations
# Iteration # 39300 completed out of  60000 iterations
# Iteration # 39400 completed out of  60000 iterations
# Iteration # 39500 completed out of  60000 iterations
# Iteration # 39600 completed out of  60000 iterations
# Iteration # 39700 completed out of  60000 iterations
# Iteration # 39800 completed out of  60000 iterations
# Iteration # 39900 completed out of  60000 iterations
# Iteration # 40000 completed out of  60000 iterations
# Iteration # 40100 completed out of  60000 iterations
# Iteration # 40200 completed out of  60000 iterations
# Iteration # 40300 completed out of  60000 iterations
# Iteration # 40400 completed out of  60000 iterations
# Iteration # 40500 completed out of  60000 iterations
# Iteration # 40600 completed out of  60000 iterations
# Iteration # 40700 completed out of  60000 iterations
# Iteration # 40800 completed out of  60000 iterations
# Iteration # 40900 completed out of  60000 iterations
# Iteration # 41000 completed out of  60000 iterations
# Iteration # 41100 completed out of  60000 iterations
# Iteration # 41200 completed out of  60000 iterations
# Iteration # 41300 completed out of  60000 iterations
# Iteration # 41400 completed out of  60000 iterations
# Iteration # 41500 completed out of  60000 iterations
# Iteration # 41600 completed out of  60000 iterations
# Iteration # 41700 completed out of  60000 iterations
# Iteration # 41800 completed out of  60000 iterations
# Iteration # 41900 completed out of  60000 iterations
# Iteration # 42000 completed out of  60000 iterations
# Iteration # 42100 completed out of  60000 iterations
# Iteration # 42200 completed out of  60000 iterations
# Iteration # 42300 completed out of  60000 iterations
# Iteration # 42400 completed out of  60000 iterations
# Iteration # 42500 completed out of  60000 iterations
# Iteration # 42600 completed out of  60000 iterations
# Iteration # 42700 completed out of  60000 iterations
# Iteration # 42800 completed out of  60000 iterations
# Iteration # 42900 completed out of  60000 iterations
# Iteration # 43000 completed out of  60000 iterations
# Iteration # 43100 completed out of  60000 iterations
# Iteration # 43200 completed out of  60000 iterations
# Iteration # 43300 completed out of  60000 iterations
# Iteration # 43400 completed out of  60000 iterations
# Iteration # 43500 completed out of  60000 iterations
# Iteration # 43600 completed out of  60000 iterations
# Iteration # 43700 completed out of  60000 iterations
# Iteration # 43800 completed out of  60000 iterations
# Iteration # 43900 completed out of  60000 iterations
# Iteration # 44000 completed out of  60000 iterations
# Iteration # 44100 completed out of  60000 iterations
# Iteration # 44200 completed out of  60000 iterations
# Iteration # 44300 completed out of  60000 iterations
# Iteration # 44400 completed out of  60000 iterations
# Iteration # 44500 completed out of  60000 iterations
# Iteration # 44600 completed out of  60000 iterations
# Iteration # 44700 completed out of  60000 iterations
# Iteration # 44800 completed out of  60000 iterations
# Iteration # 44900 completed out of  60000 iterations
# Iteration # 45000 completed out of  60000 iterations
# Iteration # 45100 completed out of  60000 iterations
# Iteration # 45200 completed out of  60000 iterations
# Iteration # 45300 completed out of  60000 iterations
# Iteration # 45400 completed out of  60000 iterations
# Iteration # 45500 completed out of  60000 iterations
# Iteration # 45600 completed out of  60000 iterations
# Iteration # 45700 completed out of  60000 iterations
# Iteration # 45800 completed out of  60000 iterations
# Iteration # 45900 completed out of  60000 iterations
# Iteration # 46000 completed out of  60000 iterations
# Iteration # 46100 completed out of  60000 iterations
# Iteration # 46200 completed out of  60000 iterations
# Iteration # 46300 completed out of  60000 iterations
# Iteration # 46400 completed out of  60000 iterations
# Iteration # 46500 completed out of  60000 iterations
# Iteration # 46600 completed out of  60000 iterations
# Iteration # 46700 completed out of  60000 iterations
# Iteration # 46800 completed out of  60000 iterations
# Iteration # 46900 completed out of  60000 iterations
# Iteration # 47000 completed out of  60000 iterations
# Iteration # 47100 completed out of  60000 iterations
# Iteration # 47200 completed out of  60000 iterations
# Iteration # 47300 completed out of  60000 iterations
# Iteration # 47400 completed out of  60000 iterations
# Iteration # 47500 completed out of  60000 iterations
# Iteration # 47600 completed out of  60000 iterations
# Iteration # 47700 completed out of  60000 iterations
# Iteration # 47800 completed out of  60000 iterations
# Iteration # 47900 completed out of  60000 iterations
# Iteration # 48000 completed out of  60000 iterations
# Iteration # 48100 completed out of  60000 iterations
# Iteration # 48200 completed out of  60000 iterations
# Iteration # 48300 completed out of  60000 iterations
# Iteration # 48400 completed out of  60000 iterations
# Iteration # 48500 completed out of  60000 iterations
# Iteration # 48600 completed out of  60000 iterations
# Iteration # 48700 completed out of  60000 iterations
# Iteration # 48800 completed out of  60000 iterations
# Iteration # 48900 completed out of  60000 iterations
# Iteration # 49000 completed out of  60000 iterations
# Iteration # 49100 completed out of  60000 iterations
# Iteration # 49200 completed out of  60000 iterations
# Iteration # 49300 completed out of  60000 iterations
# Iteration # 49400 completed out of  60000 iterations
# Iteration # 49500 completed out of  60000 iterations
# Iteration # 49600 completed out of  60000 iterations
# Iteration # 49700 completed out of  60000 iterations
# Iteration # 49800 completed out of  60000 iterations
# Iteration # 49900 completed out of  60000 iterations
# Iteration # 50000 completed out of  60000 iterations
# Iteration # 50100 completed out of  60000 iterations
# Iteration # 50200 completed out of  60000 iterations
# Iteration # 50300 completed out of  60000 iterations
# Iteration # 50400 completed out of  60000 iterations
# Iteration # 50500 completed out of  60000 iterations
# Iteration # 50600 completed out of  60000 iterations
# Iteration # 50700 completed out of  60000 iterations
# Iteration # 50800 completed out of  60000 iterations
# Iteration # 50900 completed out of  60000 iterations
# Iteration # 51000 completed out of  60000 iterations
# Iteration # 51100 completed out of  60000 iterations
# Iteration # 51200 completed out of  60000 iterations
# Iteration # 51300 completed out of  60000 iterations
# Iteration # 51400 completed out of  60000 iterations
# Iteration # 51500 completed out of  60000 iterations
# Iteration # 51600 completed out of  60000 iterations
# Iteration # 51700 completed out of  60000 iterations
# Iteration # 51800 completed out of  60000 iterations
# Iteration # 51900 completed out of  60000 iterations
# Iteration # 52000 completed out of  60000 iterations
# Iteration # 52100 completed out of  60000 iterations
# Iteration # 52200 completed out of  60000 iterations
# Iteration # 52300 completed out of  60000 iterations
# Iteration # 52400 completed out of  60000 iterations
# Iteration # 52500 completed out of  60000 iterations
# Iteration # 52600 completed out of  60000 iterations
# Iteration # 52700 completed out of  60000 iterations
# Iteration # 52800 completed out of  60000 iterations
# Iteration # 52900 completed out of  60000 iterations
# Iteration # 53000 completed out of  60000 iterations
# Iteration # 53100 completed out of  60000 iterations
# Iteration # 53200 completed out of  60000 iterations
# Iteration # 53300 completed out of  60000 iterations
# Iteration # 53400 completed out of  60000 iterations
# Iteration # 53500 completed out of  60000 iterations
# Iteration # 53600 completed out of  60000 iterations
# Iteration # 53700 completed out of  60000 iterations
# Iteration # 53800 completed out of  60000 iterations
# Iteration # 53900 completed out of  60000 iterations
# Iteration # 54000 completed out of  60000 iterations
# Iteration # 54100 completed out of  60000 iterations
# Iteration # 54200 completed out of  60000 iterations
# Iteration # 54300 completed out of  60000 iterations
# Iteration # 54400 completed out of  60000 iterations
# Iteration # 54500 completed out of  60000 iterations
# Iteration # 54600 completed out of  60000 iterations
# Iteration # 54700 completed out of  60000 iterations
# Iteration # 54800 completed out of  60000 iterations
# Iteration # 54900 completed out of  60000 iterations
# Iteration # 55000 completed out of  60000 iterations
# Iteration # 55100 completed out of  60000 iterations
# Iteration # 55200 completed out of  60000 iterations
# Iteration # 55300 completed out of  60000 iterations
# Iteration # 55400 completed out of  60000 iterations
# Iteration # 55500 completed out of  60000 iterations
# Iteration # 55600 completed out of  60000 iterations
# Iteration # 55700 completed out of  60000 iterations
# Iteration # 55800 completed out of  60000 iterations
# Iteration # 55900 completed out of  60000 iterations
# Iteration # 56000 completed out of  60000 iterations
# Iteration # 56100 completed out of  60000 iterations
# Iteration # 56200 completed out of  60000 iterations
# Iteration # 56300 completed out of  60000 iterations
# Iteration # 56400 completed out of  60000 iterations
# Iteration # 56500 completed out of  60000 iterations
# Iteration # 56600 completed out of  60000 iterations
# Iteration # 56700 completed out of  60000 iterations
# Iteration # 56800 completed out of  60000 iterations
# Iteration # 56900 completed out of  60000 iterations
# Iteration # 57000 completed out of  60000 iterations
# Iteration # 57100 completed out of  60000 iterations
# Iteration # 57200 completed out of  60000 iterations
# Iteration # 57300 completed out of  60000 iterations
# Iteration # 57400 completed out of  60000 iterations
# Iteration # 57500 completed out of  60000 iterations
# Iteration # 57600 completed out of  60000 iterations
# Iteration # 57700 completed out of  60000 iterations
# Iteration # 57800 completed out of  60000 iterations
# Iteration # 57900 completed out of  60000 iterations
# Iteration # 58000 completed out of  60000 iterations
# Iteration # 58100 completed out of  60000 iterations
# Iteration # 58200 completed out of  60000 iterations
# Iteration # 58300 completed out of  60000 iterations
# Iteration # 58400 completed out of  60000 iterations
# Iteration # 58500 completed out of  60000 iterations
# Iteration # 58600 completed out of  60000 iterations
# Iteration # 58700 completed out of  60000 iterations
# Iteration # 58800 completed out of  60000 iterations
# Iteration # 58900 completed out of  60000 iterations
# Iteration # 59000 completed out of  60000 iterations
# Iteration # 59100 completed out of  60000 iterations
# Iteration # 59200 completed out of  60000 iterations
# Iteration # 59300 completed out of  60000 iterations
# Iteration # 59400 completed out of  60000 iterations
# Iteration # 59500 completed out of  60000 iterations
# Iteration # 59600 completed out of  60000 iterations
# Iteration # 59700 completed out of  60000 iterations
# Iteration # 59800 completed out of  60000 iterations
# Iteration # 59900 completed out of  60000 iterations
# For epoch  0 /num_epoch , accuracy in training set =  0.09911666666666667
# Iteration # 0 completed out of  60000 iterations
# Iteration # 100 completed out of  60000 iterations
# Iteration # 200 completed out of  60000 iterations
# Iteration # 300 completed out of  60000 iterations
# Iteration # 400 completed out of  60000 iterations
# Iteration # 500 completed out of  60000 iterations
# Iteration # 600 completed out of  60000 iterations
# Iteration # 700 completed out of  60000 iterations
# Iteration # 800 completed out of  60000 iterations
# Iteration # 900 completed out of  60000 iterations
# Iteration # 1000 completed out of  60000 iterations
# Iteration # 1100 completed out of  60000 iterations
# Iteration # 1200 completed out of  60000 iterations
# Iteration # 1300 completed out of  60000 iterations
# Iteration # 1400 completed out of  60000 iterations
# Iteration # 1500 completed out of  60000 iterations
# Iteration # 1600 completed out of  60000 iterations
# Iteration # 1700 completed out of  60000 iterations
# Iteration # 1800 completed out of  60000 iterations
# Iteration # 1900 completed out of  60000 iterations
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-f67dcd58158a> in <module>
#      20         y = Ytrain[n_random]
#      21         x = Xtrain[n_random][:]
# ---> 22         Z, H, f = feedforward(x, y)
#      23         prediction = np.argmax(f)
#      24         if (prediction == y):
#
# <ipython-input-10-32f0bc47fe17> in feedforward(x, y)
#      18 ## Define the feed forward function for computing intermediate layers
#      19 def feedforward(x, y):
# ---> 20     Z = conv(x, parameters['K'], iteratable_forward, l_filter).reshape(l_output_map, l_output_map, num_filters)
#      21     H = tanh(Z)
#      22     U = np.tensordot(parameters['W'], H, axes = ((1,2,3),(0,1,2))) + parameters['b']
#
# <ipython-input-10-32f0bc47fe17> in conv(X, K, iteratable, l_f)
#       5 ## Define the convolution function
#       6 def conv(X, K, iteratable, l_f):
# ----> 7     conv_Z = np.array([np.tensordot(K[:,:,ijk[2]],X[ijk[0]:ijk[0]+l_f,ijk[1]:ijk[1]+l_f], axes=((0,1), (0,1))) for ijk in iteratable])
#       8     return conv_Z
#       9
#
# <ipython-input-10-32f0bc47fe17> in <listcomp>(.0)
#       5 ## Define the convolution function
#       6 def conv(X, K, iteratable, l_f):
# ----> 7     conv_Z = np.array([np.tensordot(K[:,:,ijk[2]],X[ijk[0]:ijk[0]+l_f,ijk[1]:ijk[1]+l_f], axes=((0,1), (0,1))) for ijk in iteratable])
#       8     return conv_Z
#       9
#
# C:\Anaconda\lib\site-packages\numpy\core\numeric.py in tensordot(a, b, axes)
#    1391     at = a.transpose(newaxes_a).reshape(newshape_a)
#    1392     bt = b.transpose(newaxes_b).reshape(newshape_b)
# -> 1393     res = dot(at, bt)
#    1394     return res.reshape(olda + oldb)
#    1395
#
# KeyboardInterrupt:

# %%
## Compute the test accuracy 
test_accuracy = predict(Xtest, Ytest)
print('Accuracy in testing set =', test_accuracy)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-bd35dbf48687> in <module>
#       1 ## Compute the test accuracy
# ----> 2 test_accuracy = predict(Xtest, Ytest)
#       3 print('Accuracy in testing set =', test_accuracy)
#
# <ipython-input-14-f09ad010c496> in predict(Xdata, Ydata)
#      41         y = Ydata[index]
#      42         x = Xdata[index][:]
# ---> 43         _, _, p = feedforward(x, y)
#      44         prediction = np.argmax(p)
#      45         if (prediction == y):
#
# <ipython-input-14-f09ad010c496> in feedforward(x, y)
#      18 ## Define the feed forward function for computing intermediate layers
#      19 def feedforward(x, y):
# ---> 20     Z = conv(x, parameters['K'], iteratable_forward, l_filter).reshape(l_output_map, l_output_map, num_filters)
#      21     H = tanh(Z)
#      22     U = np.tensordot(parameters['W'], H, axes = ((1,2,3),(0,1,2))) + parameters['b']
#
# <ipython-input-14-f09ad010c496> in conv(X, K, iteratable, l_f)
#       5 ## Define the convolution function
#       6 def conv(X, K, iteratable, l_f):
# ----> 7     conv_Z = np.array([np.tensordot(K[:,:,ijk[2]],X[ijk[0]:ijk[0]+l_f,ijk[1]:ijk[1]+l_f], axes=((0,1), (0,1))) for ijk in iteratable])
#       8     return conv_Z
#       9
#
# <ipython-input-14-f09ad010c496> in <listcomp>(.0)
#       5 ## Define the convolution function
#       6 def conv(X, K, iteratable, l_f):
# ----> 7     conv_Z = np.array([np.tensordot(K[:,:,ijk[2]],X[ijk[0]:ijk[0]+l_f,ijk[1]:ijk[1]+l_f], axes=((0,1), (0,1))) for ijk in iteratable])
#       8     return conv_Z
#       9
#
# C:\Anaconda\lib\site-packages\numpy\core\numeric.py in tensordot(a, b, axes)
#    1391     at = a.transpose(newaxes_a).reshape(newshape_a)
#    1392     bt = b.transpose(newaxes_b).reshape(newshape_b)
# -> 1393     res = dot(at, bt)
#    1394     return res.reshape(olda + oldb)
#    1395
#
# KeyboardInterrupt:

# %%
print(num_correct_predictions)
# Out:
# 192
